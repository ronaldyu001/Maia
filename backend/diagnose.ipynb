# %%
import sys, os
print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])
print("contains Maia?:", any(p.endswith("/2.Coding") or p.endswith("/2.Coding/Maia") for p in sys.path))
# Out:
# cwd: /Users/ronaldyu/Desktop/2.Coding/Maia/backend
# sys.path[0]: /Users/ronaldyu/.pyenv/versions/3.11.9/lib/python311.zip
# contains Maia?: False
